# %%
#YC95
#HO3

# %% [markdown]
# HO3. Remove the categorical variables in Boston Housing data the PCA with all numerical variables after normalizing data.

# %% [markdown]
# ## We start with installing the DMBA package after making sure that it is available.

# %%
pip install dmba

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pylab as plt

import dmba

# %matplotlib inline

# %%
# Load Boston Housing Data Set
bostonHousing_df = dmba.load_data('BostonHousing.csv')
bostonHousing_df = bostonHousing_df.rename(columns={'CAT. MEDV': 'CAT_MEDV'})
bostonHousing_df.head(9)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
#
#    LSTAT  MEDV  CAT_MEDV
# 0   4.98  24.0         0
# 1   9.14  21.6         0
# 2   4.03  34.7         1
# 3   2.94  33.4         1
# 4   5.33  36.2         1
# 5   5.21  28.7         0
# ...

# %%
bostonHousing_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
bostonHousing_df.CHAS.value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
# Create a bin of size 1 for a variable using the method pd.cut  By default the method creates a categorical  (6,7)
# The argument labes = False determine integers instead
bostonHousing_df['RM_bin'] = pd.cut(bostonHousing_df.RM, range(0, 10), labels=False)
bostonHousing_df.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV  CAT_MEDV  RM_bin
# 0   4.98  24.0         0       6
# 1   9.14  21.6         0       6
# 2   4.03  34.7         1       7
# 3   2.94  33.4         1       6
# 4   5.33  36.2         1       7

# %%
# Compute principal components on two dimensions
cereals_df = dmba.load_data('Cereals.csv')
pcs = PCA(n_components=2)
pcs.fit(cereals_df[['calories', 'rating']])
# Out:
# PCA(n_components=2)

# %%
# remove variables
cereals_df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4              Almond_Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat_Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
#  Components can be assessed using the explained variance
pcsSummary = pd.DataFrame({'Standard deviation': np.sqrt(pcs.explained_variance_),
                           'Proportion of variance': pcs.explained_variance_ratio_,
                           'Cumulative proportion': np.cumsum(pcs.explained_variance_ratio_)})
pcsSummary = pcsSummary.transpose()
pcsSummary.columns = ['PC1', 'PC2']
pcsSummary.round(4)
# Out:
#                             PC1     PC2
# Standard deviation      22.3165  8.8844
# Proportion of variance   0.8632  0.1368
# Cumulative proportion    0.8632  1.0000

# %%
# PCA on the two variable calories and rating
# The Columan in this matrix are the principal componets PC1, PC2.
# The rows are variable in the order they are found in the matric: calories and rating

pcsComponents_df = pd.DataFrame(pcs.components_.transpose(), columns=['PC1', 'PC2'],
                                index=['calories', 'rating'])
pcsComponents_df
# Out:
#                PC1       PC2
# calories -0.847053  0.531508
# rating    0.531508  0.847053

# %%
# Used the transfrom Method to get the scores
scores = pd.DataFrame(pcs.transform(cereals_df[['calories', 'rating']]),
                      columns=['PC1', 'PC2'])
scores.head()
# Out:
#          PC1        PC2
# 0  44.921528   2.197183
# 1 -15.725265  -0.382416
# 2  40.149935  -5.407212
# 3  75.310772  12.999126
# 4  -7.041508  -5.357686

# %%
# principale componets analysis of the whole table ignoring the first non-numerical columans
pcs = PCA()
pcs.fit(cereals_df.iloc[:, 3:].dropna(axis=0))
pcsSummary_df = pd.DataFrame({'Standard deviation': np.sqrt(pcs.explained_variance_),
                           'Proportion of variance': pcs.explained_variance_ratio_,
                           'Cumulative proportion': np.cumsum(pcs.explained_variance_ratio_)})
pcsSummary_df = pcsSummary_df.transpose()
pcsSummary_df.columns = ['PC{}'.format(i) for i in range(1, len(pcsSummary_df.columns) + 1)]
pcsSummary_df.round(4)
# Out:
#                             PC1      PC2      PC3      PC4     PC5     PC6  \
# Standard deviation      83.7641  70.9143  22.6437  19.1815  8.4232  2.0917
# Proportion of variance   0.5395   0.3867   0.0394   0.0283  0.0055  0.0003
# Cumulative proportion    0.5395   0.9262   0.9656   0.9939  0.9993  0.9997
#
#                            PC7     PC8     PC9    PC10    PC11   PC12  PC13
# Standard deviation      1.6994  0.7796  0.6578  0.3704  0.1864  0.063   0.0
# Proportion of variance  0.0002  0.0000  0.0000  0.0000  0.0000  0.000   0.0
# Cumulative proportion   0.9999  1.0000  1.0000  1.0000  1.0000  1.000   1.0

# %%
pcsComponents_df = pd.DataFrame(pcs.components_.transpose(), columns=pcsSummary_df.columns,
                                index=cereals_df.iloc[:, 3:].columns)
pcsComponents_df.iloc[:,:5]
# Out:
#                PC1       PC2       PC3       PC4       PC5
# calories -0.077984 -0.009312  0.629206 -0.601021  0.454959
# protein   0.000757  0.008801  0.001026  0.003200  0.056176
# fat       0.000102  0.002699  0.016196 -0.025262 -0.016098
# sodium   -0.980215  0.140896 -0.135902 -0.000968  0.013948
# fiber     0.005413  0.030681 -0.018191  0.020472  0.013605
# carbo    -0.017246 -0.016783  0.017370  0.025948  0.349267
# sugars   -0.002989 -0.000253  0.097705 -0.115481 -0.299066
# potass    0.134900  0.986562  0.036782 -0.042176 -0.047151
# vitamins -0.094293  0.016729  0.691978  0.714118 -0.037009
# shelf     0.001541  0.004360  0.012489  0.005647 -0.007876
# weight   -0.000512  0.000999  0.003806 -0.002546  0.003022
# cups     -0.000510 -0.001591  0.000694  0.000985  0.002148
# rating    0.075296  0.071742 -0.307947  0.334534  0.757708

# %%
## Use the preprocessing functionality in scikit-learn to standardize the data before the PCA

pcs = PCA()
pcs.fit(preprocessing.scale(cereals_df.iloc[:, 3:].dropna(axis=0)))
pcsSummary_df = pd.DataFrame({'Standard deviation': np.sqrt(pcs.explained_variance_),
                           'Proportion of variance': pcs.explained_variance_ratio_,
                           'Cumulative proportion': np.cumsum(pcs.explained_variance_ratio_)})
pcsSummary_df = pcsSummary_df.transpose()
pcsSummary_df.columns = ['PC{}'.format(i) for i in range(1, len(pcsSummary_df.columns) + 1)]
pcsSummary_df.round(4)
# Out:
#                            PC1     PC2     PC3     PC4     PC5     PC6  \
# Standard deviation      1.9192  1.7864  1.3912  1.0166  1.0015  0.8555
# Proportion of variance  0.2795  0.2422  0.1469  0.0784  0.0761  0.0555
# Cumulative proportion   0.2795  0.5217  0.6685  0.7470  0.8231  0.8786
#
#                            PC7     PC8     PC9    PC10    PC11    PC12  PC13
# Standard deviation      0.8251  0.6496  0.5658  0.3051  0.2537  0.1399   0.0
# Proportion of variance  0.0517  0.0320  0.0243  0.0071  0.0049  0.0015   0.0
# Cumulative proportion   0.9303  0.9623  0.9866  0.9936  0.9985  1.0000   1.0

# %%
pcsComponents_df = pd.DataFrame(pcs.components_.transpose(), columns=pcsSummary_df.columns,
                                index=cereals_df.iloc[:, 3:].columns)
pcsComponents_df.iloc[:,:6]
# Out:
#                PC1       PC2       PC3       PC4       PC5       PC6
# calories -0.299542 -0.393148  0.114857 -0.204359  0.203899  0.255906
# protein   0.307356 -0.165323  0.277282 -0.300743  0.319749 -0.120752
# fat      -0.039915 -0.345724 -0.204890 -0.186833  0.586893 -0.347967
# sodium   -0.183397 -0.137221  0.389431 -0.120337 -0.338364 -0.664372
# fiber     0.453490 -0.179812  0.069766 -0.039174 -0.255119 -0.064244
# carbo    -0.192449  0.149448  0.562452 -0.087835  0.182743  0.326393
# sugars   -0.228068 -0.351434 -0.355405  0.022707 -0.314872  0.152082
# potass    0.401964 -0.300544  0.067620 -0.090878 -0.148360 -0.025154
# vitamins -0.115980 -0.172909  0.387859  0.604111 -0.049287 -0.129486
# shelf     0.171263 -0.265050 -0.001531  0.638879  0.329101  0.052044
# weight   -0.050299 -0.450309  0.247138 -0.153429 -0.221283  0.398774
# cups     -0.294636  0.212248  0.140000 -0.047489  0.120816 -0.099461
# rating    0.438378  0.251539  0.181842 -0.038316  0.057584  0.186145

# %%
# thanks
